# %% [markdown]
# # Heading 1

# %% [markdown]
# ## Heading 2

# %% [markdown]
# this is heading 2 text

# %% [markdown]
# # Heading 1

# %% [markdown]
# bulleted list:
# 1. item 1
# 2. item 2
# 3. item 3
#
# <font color="orange">important</font>

# %%
print("Hello git")
# Out:
# Hello git
